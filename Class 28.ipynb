# %%
import pandas as pd

# %%
raw_data = pd.DataFrame({
    "Emp Id": [1, 2, 3, 4, 5],
    "Emp-Names": ['John', 'Jane', 'Doe', 'Alice', 'Bob'],
    "DEPT": ['HR', 'Finance', 'IT', 'Marketing', 'Sales'],
    "Salary(INR)": [50000, 60000, 55000, 70000, 65000],
    "Joining Date": ['2020-01-15', '2019-03-20', '2021-07-10', '2018-11-05', '2020-06-25']
})

# %%
raw_data
# Out:
#    Emp Id Emp-Names       DEPT  Salary(INR) Joining Date
# 0       1      John         HR        50000   2020-01-15
# 1       2      Jane    Finance        60000   2019-03-20
# 2       3       Doe         IT        55000   2021-07-10
# 3       4     Alice  Marketing        70000   2018-11-05
# 4       5       Bob      Sales        65000   2020-06-25

# %%
df = raw_data.copy()

# %%
df
# Out:
#    Emp Id Emp-Names       DEPT  Salary(INR) Joining Date
# 0       1      John         HR        50000   2020-01-15
# 1       2      Jane    Finance        60000   2019-03-20
# 2       3       Doe         IT        55000   2021-07-10
# 3       4     Alice  Marketing        70000   2018-11-05
# 4       5       Bob      Sales        65000   2020-06-25

# %%
df.columns
# Out:
# Index(['Emp Id', 'Emp-Names', 'DEPT', 'Salary(INR)', 'Joining Date'], dtype='object')

# %%
(df.columns.str.strip().str.lower().str.replace(" ","_"))
# Out:
# Index(['emp_id', 'emp-names', 'dept', 'salary(inr)', 'joining_date'], dtype='object')

# %%
(df.columns.str.strip().str.lower().str.replace(" ","_").str.replace("-","_").str.replace("[()]","",regex=True))
# Out:
# Index(['emp_id', 'emp_names', 'dept', 'salaryinr', 'joining_date'], dtype='object')

# %%
df.columns = (df.columns.str.strip().str.lower().str.replace(" ","_").str.replace("-","_").str.replace("[()]","",regex=True))

# %%
df
# Out:
#    emp_id emp_names       dept  salaryinr joining_date
# 0       1      John         HR      50000   2020-01-15
# 1       2      Jane    Finance      60000   2019-03-20
# 2       3       Doe         IT      55000   2021-07-10
# 3       4     Alice  Marketing      70000   2018-11-05
# 4       5       Bob      Sales      65000   2020-06-25

# %%
df.rename(columns={"salaryinr":"salary"})
# Out:
#    emp_id emp_names       dept  salary joining_date
# 0       1      John         HR   50000   2020-01-15
# 1       2      Jane    Finance   60000   2019-03-20
# 2       3       Doe         IT   55000   2021-07-10
# 3       4     Alice  Marketing   70000   2018-11-05
# 4       5       Bob      Sales   65000   2020-06-25

# %%
df
# Out:
#    emp_id emp_names       dept  salaryinr joining_date
# 0       1      John         HR      50000   2020-01-15
# 1       2      Jane    Finance      60000   2019-03-20
# 2       3       Doe         IT      55000   2021-07-10
# 3       4     Alice  Marketing      70000   2018-11-05
# 4       5       Bob      Sales      65000   2020-06-25

# %%
df.rename(columns={"salaryinr":"salary"},inplace=True)

# %%
df
# Out:
#    emp_id emp_names       dept  salary joining_date
# 0       1      John         HR   50000   2020-01-15
# 1       2      Jane    Finance   60000   2019-03-20
# 2       3       Doe         IT   55000   2021-07-10
# 3       4     Alice  Marketing   70000   2018-11-05
# 4       5       Bob      Sales   65000   2020-06-25

# %%
df.dtypes
# Out:
# emp_id           int64
# emp_names       object
# dept            object
# salary           int64
# joining_date    object
# dtype: object

# %%
df["joining_date"] = pd.to_datetime(df["joining_date"])

# %%
df.dtypes
# Out:
# emp_id                   int64
# emp_names               object
# dept                    object
# salary                   int64
# joining_date    datetime64[ns]
# dtype: object

# %%
df["emp_id"] = df["emp_id"].astype(int)

# %%
df.dtypes
# Out:
# emp_id                   int64
# emp_names               object
# dept                    object
# salary                   int64
# joining_date    datetime64[ns]
# dtype: object

# %%
df
# Out:
#    emp_id emp_names       dept  salary joining_date
# 0       1      John         HR   50000   2020-01-15
# 1       2      Jane    Finance   60000   2019-03-20
# 2       3       Doe         IT   55000   2021-07-10
# 3       4     Alice  Marketing   70000   2018-11-05
# 4       5       Bob      Sales   65000   2020-06-25

# %%
df["dept"] = df["dept"].str.upper()

# %%
df
# Out:
#    emp_id emp_names       dept  salary joining_date
# 0       1      John         HR   50000   2020-01-15
# 1       2      Jane    FINANCE   60000   2019-03-20
# 2       3       Doe         IT   55000   2021-07-10
# 3       4     Alice  MARKETING   70000   2018-11-05
# 4       5       Bob      SALES   65000   2020-06-25

# %%
# Sales Data Cleaning Pipeline

# %%
sales_raw = pd.DataFrame({
    "Order ID": [1, 2, 3, 4, 5],
    "Customer Id": [101, 102, 103, 104, 105],
    "Product Id": ["P1", "P2", "P3", "P3", "P2"],
    "Region": ['North', 'South', 'East', 'West', 'North'],  
    "Sales Amount": [1000, 1500, 1200, None, 1800],
    "Order Date": ['2020-01-15', '2020-02-20', '2021-03-10', '2021-04-05', '2022-05-25']
})

# %%
sales_raw
# Out:
#    Order ID  Customer Id Product Id Region  Sales Amount  Order Date
# 0         1          101         P1  North        1000.0  2020-01-15
# 1         2          102         P2  South        1500.0  2020-02-20
# 2         3          103         P3   East        1200.0  2021-03-10
# 3         4          104         P3   West           NaN  2021-04-05
# 4         5          105         P2  North        1800.0  2022-05-25

# %%
product_raw = pd.DataFrame({
    "Product Id": ["P1", "P2", "P3"],
    "Product Name": ["Laptop", "Shirt", "Sofa"],
    "category": ["Electronics", "Clothing", "Home"]
})

# %%
product_raw
# Out:
#   Product Id Product Name     category
# 0         P1       Laptop  Electronics
# 1         P2        Shirt     Clothing
# 2         P3         Sofa         Home

# %%
sales_raw.columns
# Out:
# Index(['Order ID', 'Customer Id', 'Product Id', 'Region', 'Sales Amount',
#        'Order Date'],
#       dtype='object')

# %%
sales_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      5 non-null      int64
#  1   Customer Id   5 non-null      int64
#  2   Product Id    5 non-null      object
#  3   Region        5 non-null      object
#  4   Sales Amount  4 non-null      float64
#  5   Order Date    5 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 372.0+ bytes

# %%
sales = sales_raw.copy()

# %%
sales.columns = (sales.columns.str.replace(" ","_").str.lower())

# %%
sales
# Out:
#    order_id  customer_id product_id region  sales_amount  order_date
# 0         1          101         P1  North        1000.0  2020-01-15
# 1         2          102         P2  South        1500.0  2020-02-20
# 2         3          103         P3   East        1200.0  2021-03-10
# 3         4          104         P3   West           NaN  2021-04-05
# 4         5          105         P2  North        1800.0  2022-05-25

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      5 non-null      int64
#  1   customer_id   5 non-null      int64
#  2   product_id    5 non-null      object
#  3   region        5 non-null      object
#  4   sales_amount  4 non-null      float64
#  5   order_date    5 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 372.0+ bytes

# %%
sales["order_date"] = pd.to_datetime(sales["order_date"])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      5 non-null      int64
#  1   customer_id   5 non-null      int64
#  2   product_id    5 non-null      object
#  3   region        5 non-null      object
#  4   sales_amount  4 non-null      float64
#  5   order_date    5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 372.0+ bytes

# %%
sales
# Out:
#    order_id  customer_id product_id region  sales_amount order_date
# 0         1          101         P1  North        1000.0 2020-01-15
# 1         2          102         P2  South        1500.0 2020-02-20
# 2         3          103         P3   East        1200.0 2021-03-10
# 3         4          104         P3   West           NaN 2021-04-05
# 4         5          105         P2  North        1800.0 2022-05-25

# %%
sales.isna()
# Out:
#    order_id  customer_id  product_id  region  sales_amount  order_date
# 0     False        False       False   False         False       False
# 1     False        False       False   False         False       False
# 2     False        False       False   False         False       False
# 3     False        False       False   False          True       False
# 4     False        False       False   False         False       False

# %%
sales.isna().sum()
# Out:
# order_id        0
# customer_id     0
# product_id      0
# region          0
# sales_amount    1
# order_date      0
# dtype: int64

# %%
sales["sales_amount"].mean()
# Out:
# np.float64(1375.0)

# %%
sales["sales_amount"].fillna(sales["sales_amount"].mean())
# Out:
# 0    1000.0
# 1    1500.0
# 2    1200.0
# 3    1375.0
# 4    1800.0
# Name: sales_amount, dtype: float64

# %%
sales
# Out:
#    order_id  customer_id product_id region  sales_amount order_date
# 0         1          101         P1  North        1000.0 2020-01-15
# 1         2          102         P2  South        1500.0 2020-02-20
# 2         3          103         P3   East        1200.0 2021-03-10
# 3         4          104         P3   West           NaN 2021-04-05
# 4         5          105         P2  North        1800.0 2022-05-25

# %%
sales["sales_amount"].fillna(sales["sales_amount"].mean(),inplace=True)
# Out:
# C:\Users\Chinna\AppData\Local\Temp\ipykernel_5976\1868453458.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sales["sales_amount"].fillna(sales["sales_amount"].mean(),inplace=True)

# %%
sales.fillna({"sales_amount":sales["sales_amount"].mean()},inplace=True)

# %%
sales
# Out:
#    order_id  customer_id product_id region  sales_amount order_date
# 0         1          101         P1  North        1000.0 2020-01-15
# 1         2          102         P2  South        1500.0 2020-02-20
# 2         3          103         P3   East        1200.0 2021-03-10
# 3         4          104         P3   West        1375.0 2021-04-05
# 4         5          105         P2  North        1800.0 2022-05-25

# %%
sales
# Out:
#    order_id  customer_id product_id region  sales_amount order_date
# 0         1          101         P1  North        1000.0 2020-01-15
# 1         2          102         P2  South        1500.0 2020-02-20
# 2         3          103         P3   East        1200.0 2021-03-10
# 3         4          104         P3   West        1375.0 2021-04-05
# 4         5          105         P2  North        1800.0 2022-05-25

# %%
df = sales[sales["sales_amount"]<=1500]

# %%
df
# Out:
#    order_id  customer_id product_id region  sales_amount order_date
# 0         1          101         P1  North        1000.0 2020-01-15
# 1         2          102         P2  South        1500.0 2020-02-20
# 2         3          103         P3   East        1200.0 2021-03-10
# 3         4          104         P3   West        1375.0 2021-04-05

# %%
df.sort_values(by="sales_amount", ascending= False,inplace=True)
# Out:
# C:\Users\Chinna\AppData\Local\Temp\ipykernel_5976\809801825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values(by="sales_amount", ascending= False,inplace=True)

# %%
df
# Out:
#    order_id  customer_id product_id region  sales_amount order_date
# 1         2          102         P2  South        1500.0 2020-02-20
# 3         4          104         P3   West        1375.0 2021-04-05
# 2         3          103         P3   East        1200.0 2021-03-10
# 0         1          101         P1  North        1000.0 2020-01-15

# %%
product_raw
# Out:
#   Product Id Product Name     category
# 0         P1       Laptop  Electronics
# 1         P2        Shirt     Clothing
# 2         P3         Sofa         Home

# %%
product_raw.columns = (product_raw.columns.str.replace(" ","_").str.lower())

# %%
product_raw
# Out:
#   product_id product_name     category
# 0         P1       Laptop  Electronics
# 1         P2        Shirt     Clothing
# 2         P3         Sofa         Home

# %%
sales_with_cat_df = pd.merge(df,product_raw, on = "product_id", how="inner")

# %%
sales_with_cat_df
# Out:
#    order_id  customer_id product_id region  sales_amount order_date  \
# 0         2          102         P2  South        1500.0 2020-02-20
# 1         4          104         P3   West        1375.0 2021-04-05
# 2         3          103         P3   East        1200.0 2021-03-10
# 3         1          101         P1  North        1000.0 2020-01-15
#
#   product_name     category
# 0        Shirt     Clothing
# 1         Sofa         Home
# 2         Sofa         Home
# 3       Laptop  Electronics

# %%
sales_with_cat_df.groupby("category")["sales_amount"].sum()
# Out:
# category
# Clothing       1500.0
# Electronics    1000.0
# Home           2575.0
# Name: sales_amount, dtype: float64

# %%
sales_with_cat_df.groupby("region")["sales_amount"].sum()
# Out:
# region
# East     1200.0
# North    1000.0
# South    1500.0
# West     1375.0
# Name: sales_amount, dtype: float64

# %%
sales_with_cat_df.to_csv("sales_with_cat_df.csv")

# %%
sales_with_cat_df.to_csv("sales_with_cat_df.csv", index=False)

# %%
sales_with_cat_df.to_excel("sales_with_cat_df.xlsx")

# %%
sales_with_cat_df.to_excel("sales_with_cat_df.xlsx",index=False)

# %%
cust_df = pd.read_json("cust.json")

# %%
cust_df
# Out:
#    id           name                   email        phone  \
# 0   1     John Smith  john.smith@example.com  +1-555-0101
# 1   2  Sarah Johnson     sarah.j@example.com  +1-555-0102
# 2   3   Michael Chen      m.chen@example.com  +1-555-0103
#
#                               address registeredDate
# 0     123 Main St, New York, NY 10001     2023-01-15
# 1  456 Oak Ave, Los Angeles, CA 90001     2023-06-20
# 2      789 Pine Rd, Chicago, IL 60601     2024-02-10

# %%
order_df = pd.read_csv("order.csv")

# %%
order_df.head(2)
# Out:
#    order_id  customer_name product  quantity   price  order_date     status
# 0      1001     John Smith  Laptop         1  999.99  2025-01-15  Completed
# 1      1002  Sarah Johnson   Mouse         5   29.99  2025-01-16  Completed

# %%
order_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       15 non-null     int64
#  1   customer_name  15 non-null     object
#  2   product        15 non-null     object
#  3   quantity       15 non-null     int64
#  4   price          15 non-null     float64
#  5   order_date     15 non-null     object
#  6   status         15 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 972.0+ bytes

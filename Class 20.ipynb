# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 1, 26, 9, 15, 17, 485099)

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 1, 26, 9, 16, 7, 303910)

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2026, 1, 26)

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2026, 1, 26, 9, 17, 59, 605164)

# %%
now.strftime('%Y-%m-%d')
# Out:
# '2026-01-26'

# %%
now.strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2026-01-26 09:17:59'

# %%
now #Year, Month, Day, Hour, Minute, Second, MicroSecond)
# Out:
# datetime.datetime(2026, 1, 26, 9, 17, 59, 605164)

# %%
from datetime import time

# %%
time(9,20)
# Out:
# datetime.time(9, 20)

# %%
t = time(9,20,5)

# %%
t
# Out:
# datetime.time(9, 20, 5)

# %%
from datetime import date

# %%
d= date(2026,1,26)

# %%
d
# Out:
# datetime.date(2026, 1, 26)

# %%
from datetime import datetime

# %%
dt = datetime(2026,1,26,9,24,10)

# %%
dt
# Out:
# datetime.datetime(2026, 1, 26, 9, 24, 10)

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 1, 26, 9, 24, 24, 493403)

# %%
dt = datetime.strftime(datetime.now(),'%Y_%m_%d_%H_%M_%S')

# %%
dt
# Out:
# '2026_01_26_09_26_22'

# %%
current_filename = f"Orders_{dt}.csv"

# %%
current_filename
# Out:
# 'Orders_2026_01_26_09_26_22.csv'

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\DE 202512\\CodeFiles'

# %%
#  W  --  \       \\
#  Linux  -  /

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Class 16.ipynb',
#  'Class 17.ipynb',
#  'Class 18.ipynb',
#  'Class 19.ipynb',
#  'Class15.ipynb',
#  'data',
#  'etl.log',
#  'test.ipynb',
#  'Untitled.ipynb',
#  'writedemofile.txt',
#  'writedemofile_1.txt']

# %%
os.path.exists("date.txt")
# Out:
# False

# %%
os.path.isfile("etl.log")
# Out:
# True

# %%
os.path.isdir("data")
# Out:
# True

# %%
import logging

# %%
logging.basicConfig(filename='app.log', filemode='w', 
                    level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')

# %%
logger = logging.getLogger()

# %%
logger.setLevel(logging.DEBUG)

# %%
file_handler = logging.FileHandler("etl.log")

# %%
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

# %%
file_handler.setFormatter(formatter)

# %%
logger.addHandler(file_handler)

# %%
logger.info("This is Info")

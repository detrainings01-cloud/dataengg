# %%
# Pandas   --> Data Structures

# %%
# Series          -->  1-D labeled array 
# DataFrame       -->  2-D labeled array

# %%
import pandas as pd

# %%
nums = [10,20,30,40]

# %%
s = pd.Series(nums)

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = pd.Series([1,2,3,4],index=['a','b','c','d'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
d = {"Abe":"US","Bob":"Canada","Charan":"India"}

# %%
d
# Out:
# {'Abe': 'US', 'Bob': 'Canada', 'Charan': 'India'}

# %%
s = pd.Series(d)

# %%
s
# Out:
# Abe           US
# Bob       Canada
# Charan     India
# dtype: object

# %%
s.values
# Out:
# array(['US', 'Canada', 'India'], dtype=object)

# %%
s.index
# Out:
# Index(['Abe', 'Bob', 'Charan'], dtype='object')

# %%
s.dtype
# Out:
# dtype('O')

# %%
s = pd.Series([10,20,30])

# %%
s+10
# Out:
# 0    20
# 1    30
# 2    40
# dtype: int64

# %%
s*2
# Out:
# 0    20
# 1    40
# 2    60
# dtype: int64

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s[s>10]
# Out:
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({"Name":["Abe","Bob","Charam"],"Age":[20,30,40],"City":["Hyd","Chennai","Blr"]})

# %%
df   #  Columns Labels  | Rows  Index
# Out:
#      name  Age     City
# 0     Abe   20      Hyd
# 1     Bob   30  Chennai
# 2  Charam   40      Blr

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Name":["Abe","Bob","Charam"],"Age":[20,30,40],"City":["Hyd","Chennai","Blr"]}, index=["rec_1","rec_2","rec_3"])

# %%
df
# Out:
#          Name  Age     City
# rec_1     Abe   20      Hyd
# rec_2     Bob   30  Chennai
# rec_3  Charam   40      Blr

# %%
data = [{"name":"A","Salary":10000},{"name":"B","Salary":20000} ]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   name  Salary
# 0    A   10000
# 1    B   20000

# %%
data = [{"name":"A","Salary":10000},{"name":"B","Salary":20000, "City":"Hyd"} ]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   name  Salary City
# 0    A   10000  NaN
# 1    B   20000  Hyd

# %%
df.shape
# Out:
# (2, 3)

# %%
df.columns
# Out:
# Index(['name', 'Salary', 'City'], dtype='object')

# %%
df.index
# Out:
# Index(['rec_1', 'rec_2', 'rec_3'], dtype='object')

# %%
df.dtypes
# Out:
# name      object
# Salary     int64
# City      object
# dtype: object

# %%
df
# Out:
#   name  Salary City
# 0    A   10000  NaN
# 1    B   20000  Hyd

# %%
df["Salary"]
# Out:
# 0    10000
# 1    20000
# Name: Salary, dtype: int64

# %%
type(df["Salary"])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
sal_series = pd.Series([1000,2000,3000])

# %%
type(sal_series)
# Out:
# pandas.core.series.Series

# %%
sal_series.to_frame(name="Salary")
# Out:
#    Salary
# 0    1000
# 1    2000
# 2    3000

# %%
df
# Out:
#   name  Salary City
# 0    A   10000  NaN
# 1    B   20000  Hyd

# %%
df["Salary"]   # Series
# Out:
# 0    10000
# 1    20000
# Name: Salary, dtype: int64

# %%
df
# Out:
#   name  Salary City
# 0    A   10000  NaN
# 1    B   20000  Hyd

# %%
df['City']
# Out:
# 0    NaN
# 1    Hyd
# Name: City, dtype: object

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df[0]
#
# ...

# %%
df
# Out:
#   name  Salary City
# 0    A   10000  NaN
# 1    B   20000  Hyd

# %%
df.loc[0]
# Out:
# name          A
# Salary    10000
# City        NaN
# Name: 0, dtype: object

# %%
df.loc[0,"Salary"]
# Out:
# np.int64(10000)

# %%
s1 = pd.Series([10,20],index=["A","B"])
s2 = pd.Series([20,30],index=["B","C"])

# %%
s1
# Out:
# A    10
# B    20
# dtype: int64

# %%
s2
# Out:
# B    20
# C    30
# dtype: int64

# %%
s1+s2   #  Alignment is happenning using Index
# Out:
# A     NaN
# B    40.0
# C     NaN
# dtype: float64

# %%
df1 = pd.DataFrame({"A":[10,20,30],"B":[15,25,35]})

# %%
df1
# Out:
#     A   B
# 0  10  15
# 1  20  25
# 2  30  35

# %%
df2 = pd.DataFrame({"A":[9,15,25],"B":[10,15,25]})

# %%
df2
# Out:
#     A   B
# 0   9  10
# 1  15  15
# 2  25  25

# %%
df1+df2    #  Allignment will happen using rows and columns
# Out:
#     A   B
# 0  19  25
# 1  35  40
# 2  55  60

# %%
df
# Out:
#   name  Salary City
# 0    A   10000  NaN
# 1    B   20000  Hyd

# %%
df.isna()
# Out:
#     name  Salary   City
# 0  False   False   True
# 1  False   False  False

# %%
df.fillna("No City")
# Out:
#   name  Salary     City
# 0    A   10000  No City
# 1    B   20000      Hyd

# %%
df
# Out:
#   name  Salary City
# 0    A   10000  NaN
# 1    B   20000  Hyd

# %%
df.dropna()
# Out:
#   name  Salary City
# 1    B   20000  Hyd

# %%
orders_df = pd.DataFrame({"Order_id": [1, 2, 3, 4, 5],
                       "Customer_id": [101, 102, 101, 103, 101],
                       "Product": ["A", "B", "C", "D", "A"],
                       "Price": [10.0, 20.0, 15.0, 25.0, 35.0],
                       "Status": ["Shipped", "Pending", "Delivered", "Shipped", "Delivered"]})

# %%
orders_df
# Out:
#    Order_id  Customer_id Product  Price     Status
# 0         1          101       A   10.0    Shipped
# 1         2          102       B   20.0    Pending
# 2         3          101       C   15.0  Delivered
# 3         4          103       D   25.0    Shipped
# 4         5          101       A   35.0  Delivered

# %%
orders_df["Status"]
# Out:
# 0      Shipped
# 1      Pending
# 2    Delivered
# 3      Shipped
# 4    Delivered
# Name: Status, dtype: object

# %%
orders_df[orders_df["Status"] == "Delivered"]
# Out:
#    Order_id  Customer_id Product  Price     Status
# 2         3          101       C   15.0  Delivered
# 4         5          101       A   35.0  Delivered

# %%
orders_df[orders_df["Status"] == "Delivered"]["Price"]
# Out:
# 2    15.0
# 4    35.0
# Name: Price, dtype: float64

# %%
orders_df[orders_df["Status"] == "Delivered"]["Price"].sum()
# Out:
# np.float64(50.0)

# %%
orders_df[orders_df["Status"] == "Pending"]
# Out:
#    Order_id  Customer_id Product  Price   Status
# 1         2          102       B   20.0  Pending

# %%
orders_df = pd.read_csv("order.csv")

# %%
orders_df
# Out:
#     order_id     customer_name           product  quantity   price  \
# 0       1001        John Smith            Laptop         1  999.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 3       1004       Emma Wilson           Monitor         1  349.99
# 4       1005       James Brown        Headphones         3  149.99
# 5       1006     Lisa Anderson         USB Cable        10    9.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 12      1013      Kevin Miller       Phone Stand         8   19.99
# ...

# %%
orders_df[orders_df["status"] == 'Completed']   #  select * from order where status = 'Completed'
# Out:
#     order_id     customer_name           product  quantity   price  \
# 0       1001        John Smith            Laptop         1  999.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 4       1005       James Brown        Headphones         3  149.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 13      1014     Jessica Davis  External HDD 2TB         3   79.99
#
#     order_date     status
# 0   2025-01-15  Completed
# 1   2025-01-16  Completed
# 4   2025-01-19  Completed
# 6   2025-01-21  Completed
# 9   2025-01-24  Completed
# 11  2025-01-26  Completed
# 13  2025-01-28  Completed

# %%
orders_df[orders_df["status"] == 'Completed']['price'].sum()   # select sum(price) from orders where status = 'Completed'
# Out:
# np.float64(1439.93)

# %%
orders_df["total_price"] = orders_df["quantity"] * orders_df["price"]

# %%
orders_df
# Out:
#     order_id     customer_name           product  quantity   price  \
# 0       1001        John Smith            Laptop         1  999.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 3       1004       Emma Wilson           Monitor         1  349.99
# 4       1005       James Brown        Headphones         3  149.99
# 5       1006     Lisa Anderson         USB Cable        10    9.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 12      1013      Kevin Miller       Phone Stand         8   19.99
# ...

# %%
orders_df[orders_df["status"] == 'Completed']['total_price'].sum()
# Out:
# np.float64(2309.79)

# %%
orders_df[orders_df["status"] == 'Completed']['total_price'].mean()
# Out:
# np.float64(329.96999999999997)

# %%
orders_df[orders_df["status"] == 'Completed']['order_id'].count()
# Out:
# np.int64(7)

# %%
orders_df
# Out:
#     order_id     customer_name           product  quantity   price  \
# 0       1001        John Smith            Laptop         1  999.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 3       1004       Emma Wilson           Monitor         1  349.99
# 4       1005       James Brown        Headphones         3  149.99
# 5       1006     Lisa Anderson         USB Cable        10    9.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 12      1013      Kevin Miller       Phone Stand         8   19.99
# ...

# %%
['total_price_tax'] = orders_df['total_price'] * 1.18

# %%
 orders_df
# Out:
#     order_id     customer_name           product  quantity   price  \
# 0       1001        John Smith            Laptop         1  999.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 3       1004       Emma Wilson           Monitor         1  349.99
# 4       1005       James Brown        Headphones         3  149.99
# 5       1006     Lisa Anderson         USB Cable        10    9.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 12      1013      Kevin Miller       Phone Stand         8   19.99
# ...

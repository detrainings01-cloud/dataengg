# %%
# Tuples - Ordered collection of elements which are immutable

# %%
my_tuple = ('apple','banana','cherry')

# %%
type(my_tuple)
# Out:
# tuple

# %%
tuple_1 = (1,2,3,'a','b','Hello')

# %%
type(tuple_1)
# Out:
# tuple

# %%
tuple_2 = (1,2,3,'a','b','Hello',[1,2])

# %%
type(tuple_2)
# Out:
# tuple

# %%
my_tuple  # Ordered
# Out:
# ('apple', 'banana', 'cherry')

# %%
my_tuple.append('mango')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2532493420.py in <cell line: 0>()
# ----> 1 my_tuple.append('mango')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
my_tuple.remove('apple')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3863202880.py in <cell line: 0>()
# ----> 1 my_tuple.remove('apple')
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry')

# %%
my_tuple[0]
# Out:
# 'apple'

# %%
my_tuple[0] = 'mango'  #  immutable - can not change after we create
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1225398688.py in <cell line: 0>()
# ----> 1 my_tuple[0] = 'mango'  #  immutable - can not change after we create
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple[-1]
# Out:
# 'cherry'

# %%
tuple_2
# Out:
# (1, 2, 3, 'a', 'b', 'Hello', [1, 2])

# %%
tuple_2[3:]
# Out:
# ('a', 'b', 'Hello', [1, 2])

# %%
tuple_2[3:5]
# Out:
# ('a', 'b')

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry')

# %%
for item in my_tuple:
  print(item)
# Out:
# apple
# banana
# cherry

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry')

# %%
if 'apple' in my_tuple:
  print(f'apple is present in the {my_tuple}')
# Out:
# apple is present in the ('apple', 'banana', 'cherry')

# %%
if 'apple111' in my_tuple:
  print(f'apple111 is present in the {my_tuple}')

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry')

# %%
my_another_tuple = my_tuple.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2143366078.py in <cell line: 0>()
# ----> 1 my_another_tuple = my_tuple.copy()
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry')

# %%
my_tuple_list = list(my_tuple)

# %%
my_tuple_list
# Out:
# ['apple', 'banana', 'cherry']

# %%
my_tuple_list.append('mango')

# %%
my_tuple = tuple(my_tuple_list)

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry', 'mango')

# %%
my_emp_data = [(1,'John',25000),(2,'Abe',60000),(3,'Charan',65000)]   # emp - emp_id, emp_name, sal

# %%
my_emp_data
# Out:
# [(1, 'John', 25000), (2, 'Abe', 60000), (3, 'Charan', 65000)]

# %%
my_emp_data[1]
# Out:
# (2, 'Abe', 60000)

# %%
for emp in my_emp_data:
  print(f'emp_id is {emp[0]} |  Name is {emp[1]}  | Salary is {emp[2]}')
# Out:
# emp_id is 1 |  Name is John  | Salary is 25000
# emp_id is 2 |  Name is Abe  | Salary is 60000
# emp_id is 3 |  Name is Charan  | Salary is 65000

# %%
my_emp_data
# Out:
# [(1, 'John', 25000), (2, 'Abe', 60000), (3, 'Charan', 65000)]

# %%
for emp in my_emp_data:
  print(f'emp_id is {emp[0]} |  Name is {emp[1]}  | Salary is {emp[2]}')

# %%
for emp in my_emp_data:
  if emp[0] != 2:
    print(f'emp_id is {emp[0]} |  Name is {emp[1]}  | Salary is {emp[2]}')
# Out:
# emp_id is 1 |  Name is John  | Salary is 25000
# emp_id is 3 |  Name is Charan  | Salary is 65000

# %%
#  tuple unpacking

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry', 'mango')

# %%
a,b,c,d = my_tuple

# %%
a
# Out:
# 'apple'

# %%
b
# Out:
# 'banana'

# %%
my_list = [1,2,3]
for i in my_list:
  print(i)
# Out:
# 1
# 2
# 3

# %%
my_tuple
# Out:
# ('apple', 'banana', 'cherry', 'mango')

# %%
for i in my_tuple:
  print(i)
# Out:
# apple
# banana
# cherry
# mango

# %%
len(my_tuple)
# Out:
# 4

# %%
tuple_1 = (1,2,3)
tuple_2 = ('a','b','c')

# %%
tuple_1 + tuple_2
# Out:
# (1, 2, 3, 'a', 'b', 'c')

# %%
tuple_1
# Out:
# (1, 2, 3)

# %%
tuple_2
# Out:
# ('a', 'b', 'c')

# %%
tuple_1
# Out:
# (1, 2, 3)

# %%
tuple_1  * 2
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
i  =  (1,2,3)

# %%
type(i)
# Out:
# tuple

# %%
i = (3,4,5,6)

# %%
i
# Out:
# (3, 4, 5, 6)

# %%
i
# Out:
# (3, 4, 5, 6)

# %%
i.index(5)
# Out:
# 2

# %%
i.count(3)
# Out:
# 1

# %%
i.count(0)
# Out:
# 0

# %%
# Sets  # Unordered collection of elements

# %%
my_set = {"apple","banana","orange"}

# %%
my_set
# Out:
# {'apple', 'banana', 'orange'}

# %%
type(my_set)
# Out:
# set

# %%
my_set = {"apple","orange","banana"}

# %%
my_set   # Un ordered
# Out:
# {'apple', 'banana', 'orange'}

# %%
my_set = {"apple","orange","banana","apple"}

# %%
my_set     #  No duplicates   -  Sets will not have same value elements
# Out:
# {'apple', 'banana', 'orange'}

# %%
bool(1)
# Out:
# True

# %%
my_set = {"apple","orange","banana",True,1,2}   #  True and 1 are treated as same values

# %%
my_set
# Out:
# {2, True, 'apple', 'banana', 'orange'}

# %%
my_set = {"apple","orange","banana",False,0,2}    #  False and 0 are treated as same values

# %%
my_set
# Out:
# {2, False, 'apple', 'banana', 'orange'}

# %%
my_set = {"apple","orange","banana",1, True ,2}

# %%
my_set
# Out:
# {1, 2, 'apple', 'banana', 'orange'}

# %%
my_list = [1,2,3,4,1,2,3,4,5,6]

# %%
my_list = list(set(my_list))

# %%
my_list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
my_set
# Out:
# {1, 2, 'apple', 'banana', 'orange'}

# %%
len(my_set)
# Out:
# 5

# %%
for i in my_set:
  print(i)
# Out:
# 1
# 2
# apple
# orange
# banana

# %%
if 'apple' in my_set:
  print('apple preset')
# Out:
# appple preset

# %%
my_set
# Out:
# {1, 2, 'apple', 'banana', 'orange'}

# %%
my_set[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1534144899.py in <cell line: 0>()
# ----> 1 my_set[1]
#
# TypeError: 'set' object is not subscriptable

# %%
my_set[1] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2073003764.py in <cell line: 0>()
# ----> 1 my_set[1] = 2
#
# TypeError: 'set' object does not support item assignment

# %%
my_set
# Out:
# {1, 2, 'apple', 'banana', 'orange'}

# %%
my_set.add('mango')

# %%
my_set
# Out:
# {1, 2, 'apple', 'banana', 'mango', 'orange'}

# %%
set_1  = {1,2,3}
set_2  = {'a','b','c'}

# %%
set_1
# Out:
# {1, 2, 3}

# %%
set_2
# Out:
# {'a', 'b', 'c'}

# %%
set_1.update(set_2)

# %%
set_1
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set_1
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set_1_copy = set_1.copy()

# %%
set_1_copy
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set_1
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set_1.remove('a')

# %%
set_1
# Out:
# {1, 2, 3, 'b', 'c'}

# %%
set_1.remove('d')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4154235677.py in <cell line: 0>()
# ----> 1 set_1.remove('d')
#
# KeyError: 'd'

# %%
set_1
# Out:
# {1, 2, 3, 'b', 'c'}

# %%
set_1.discard('d')

# %%
set_1.discard('b')

# %%
set_1
# Out:
# {1, 2, 3, 'c'}

# %%
set_1.pop()
# Out:
# 1

# %%
set_1
# Out:
# {2, 3, 'c'}

# %%
set_1.clear()

# %%
set_1
# Out:
# set()

# %%
del set_1

# %%
set_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1907301559.py in <cell line: 0>()
# ----> 1 set_1
#
# NameError: name 'set_1' is not defined

# %%
set_1  = {1,2,3}
set_2  = {'a','b','c'}

# %%
set_1.union(set_2)
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
set_1
# Out:
# {1, 2, 3}

# %%
set_1 | set_2
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %%
import logging
import os
print("Working directory:", os.getcwd()) 
logging.basicConfig(
    filename="etl.log",
    level=logging.DEBUG,
    format="%(asctime)s | %(levelname)s | %(message)s"
)
logging.debug("Debug")
logging.info("Job started")
logging.warning("File size is large")
logging.error("File not found")
# Out:
# 2026-01-24 13:56:00,907 | INFO | Job started
# 2026-01-24 13:56:00,909 | WARNING | File size is large
# 2026-01-24 13:56:00,910 | ERROR | File not found
# Working directory: D:\DE 202512\CodeFiles

# %%
import logging

for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

logging.basicConfig(
    filename="etl.log",
    level=logging.DEBUG,
    format="%(asctime)s | %(levelname)s | %(message)s"
)

logging.info("Job started")

# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

file_handler = logging.FileHandler("etl.log")
formatter = logging.Formatter("%(asctime)s | %(levelname)s | %(message)s")
file_handler.setFormatter(formatter)

logger.addHandler(file_handler)

logger.info("Job started")

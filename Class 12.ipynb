# %%
# [1,2,3,4,5]   -->  [1,4,9,16,25]

# %%
in_nums = [1,2,3,4,5]
sq_nums = []
for i in in_nums:
  sq_nums.append(i*i)
print(sq_nums)
# Out:
# [1, 4, 9, 16, 25]

# %%
[i*i  for i in in_nums]   #  List comprehension
# Out:
# [1, 4, 9, 16, 25]

# %%
def my_square(nums):
  sq_nums = []
  for i in in_nums:
    sq_nums.append(i*i)
  print(sq_nums)

# %%
my_square(in_nums)
# Out:
# [1, 4, 9, 16, 25]

# %%
my_upper = lambda s : s.upper()

# %%
my_upper("Abe")
# Out:
# 'ABE'

# %%
my_upper(["Abe","Bob"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4228440592.py in <cell line: 0>()
# ----> 1 my_upper(["Abe","Bob"])
#
# /tmp/ipython-input-1493671213.py in <lambda>(s)
# ----> 1 my_upper = lambda s : s.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
my_upper = lambda s : [i.upper() for i in s]

# %%
my_upper(["Abe","Bob"])
# Out:
# ['ABE', 'BOB']

# %%
# map()  applies a function to every element in an iterable object
# map(function, iterable)

# %%
my_upper_lbd = lambda s: s.upper()

# %%
my_upper_lbd('Abe')
# Out:
# 'ABE'

# %%
list(map(my_upper_lbd,['Abe','Bob']))
# Out:
# ['ABE', 'BOB']

# %%
my_nums = [1,5,2,3,4]

# %%
list(map(lambda a:a*2 , my_nums))
# Out:
# [2, 10, 4, 6, 8]

# %%
def my_square(a):
  return a*a

# %%
list(map(my_square, my_nums))
# Out:
# [1, 25, 4, 9, 16]

# %%
# filter    #  List of items for which the function returns True

# %%
my_nums
# Out:
# [1, 5, 2, 3, 4]

# %%
def is_even(a):
  if a%2 == 0:
    return a

# %%
is_even(10)
# Out:
# 10

# %%
def is_even(a):
  if a%2 == 0:
    return True
  else:
    return False

# %%
is_even(10)
# Out:
# True

# %%
my_nums
# Out:
# [1, 5, 2, 3, 4]

# %%
list(map(is_even,my_nums))
# Out:
# [False, False, True, False, True]

# %%
list(map(lambda a: a%2 == 0 , my_nums))
# Out:
# [False, False, True, False, True]

# %%
list(filter(lambda a: a%2 == 0 , my_nums))
# Out:
# [2, 4]

# %%
list(filter(is_even, my_nums))
# Out:
# [2, 4]

# %%
# Reduce --> Reduce the list of elements in to a single value

# %%
from functools import reduce

# %%
my_nums
# Out:
# [1, 5, 2, 3, 4]

# %%
reduce(lambda a,b: a+b , my_nums)
#   1 5 = 6
#   6  2 = 8
#   8  3 = 11
#   11   4 = 15
# Out:
# 15

# %%
marks = [35, 25, 100, 90]
# pass mark>35   # map, reduce, filter ?
#my_out = [100, 90 ]
list(filter(lambda mark: mark>35, marks))
# Out:
# [100, 90]

# %%
marks = [35, 25, 100, 90]
#  map, reduce, filter?
reduce(lambda m1,m2:m1+m2, marks)
# Out:
# 250

# %%
# sorted()    # used to sort the elements

# %%
my_nums
# Out:
# [1, 5, 2, 3, 4]

# %%
sorted(my_nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(my_nums, reverse = True)
# Out:
# [5, 4, 3, 2, 1]

# %%
fruit_names = ['mango','apple','Banana','Cherry']

# %%
sorted(fruit_names)   # ['apple', 'Banana', 'Cherry',  'mango']
# Out:
# ['Banana', 'Cherry', 'apple', 'mango']

# %%
str.lower('Banana')
# Out:
# 'banana'

# %%
'Banana'.lower()
# Out:
# 'banana'

# %%
sorted(fruit_names, key=str.lower )
# Out:
# ['apple', 'Banana', 'Cherry', 'mango']

# %%
len('apple')
# Out:
# 5

# %%
fruit_names
# Out:
# ['mango', 'apple', 'Banana', 'Cherry']

# %%
sorted(fruit_names, key=len)
# Out:
# ['mango', 'apple', 'Banana', 'Cherry']

# %%
my_nums = [-10, -20, 10, 0, -30, 30]

# %%
sorted(my_nums)   #  [0, -10, 10, -20, -30, 30]
# Out:
# [-30, -20, -10, 0, 10, 30]

# %%
abs(-30)
# Out:
# 30

# %%
sorted(my_nums, key = abs)
# Out:
# [0, -10, 10, -20, -30, 30]

# %%
student_names = [("Abe",35),("Cherry",50),("Bob",25),("Dam",45)]

# %%
sorted(student_names)
# Out:
# [('Abe', 35), ('Bob', 25), ('Cherry', 50), ('Dam', 45)]

# %%
sorted(student_names, key= lambda x:x[1])
# Out:
# [('Bob', 25), ('Abe', 35), ('Dam', 45), ('Cherry', 50)]

# %%
my_employees = [{"name":"Abe","Salary":35000}, {"name":"Cherry","Salary":50000} ,
                {"name":"Bob","Salary":25000}, {"name":"Dam","Salary":45000}]

# %%
my_employees
# Out:
# [{'name': 'Abe', 'Salary': 35000},
#  {'name': 'Cherry', 'Salary': 50000},
#  {'name': 'Bob', 'Salary': 25000},
#  {'name': 'Dam', 'Salary': 45000}]

# %%
sorted(my_employees, key = lambda my_emp : my_emp['Salary'])
# Out:
# [{'name': 'Bob', 'Salary': 25000},
#  {'name': 'Abe', 'Salary': 35000},
#  {'name': 'Dam', 'Salary': 45000},
#  {'name': 'Cherry', 'Salary': 50000}]

# %%
sorted(my_employees, key = lambda my_emp : my_emp['Salary'], reverse =True)
# Out:
# [{'name': 'Cherry', 'Salary': 50000},
#  {'name': 'Dam', 'Salary': 45000},
#  {'name': 'Abe', 'Salary': 35000},
#  {'name': 'Bob', 'Salary': 25000}]

# %%
my_nums
# Out:
# [-10, -20, 10, 0, -30, 30]

# %%
my_nums.sort()

# %%
my_nums
# Out:
# [-30, -20, -10, 0, 10, 30]

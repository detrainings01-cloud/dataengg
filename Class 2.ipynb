# %%
x = 10

# %%
type(x)
# Out:
# int

# %%
x = 12

# %%
x
# Out:
# 12

# %%
type(x)
# Out:
# int

# %%
f = 12.3

# %%
f
# Out:
# 12.3

# %%
type(f)
# Out:
# float

# %%
x
# Out:
# 12

# %%
type(x)
# Out:
# int

# %%
x = 25.3

# %%
type(x)
# Out:
# float

# %%
# int x = 10;

# %%
c = 'a'

# %%
type(c)
# Out:
# str

# %%
greet_msg = "Hello World"

# %%
print(greet_msg)
# Out:
# Hello World

# %%
greet_msg
# Out:
# 'Hello World'

# %%
type(greet_msg)
# Out:
# str

# %%
is_active = True

# %%
type(is_active)
# Out:
# bool

# %%
is_active = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1846615141.py in <cell line: 0>()
# ----> 1 is_active = true
#
# NameError: name 'true' is not defined

# %%
is_active = True

# %%
is_active = 'True'

# %%
type(is_active)
# Out:
# str

# %%
1st_time = 10    #  We cannot start a var name with numbers
# Out:
#   File "/tmp/ipython-input-695822307.py", line 1
#     1st_time = 10
#     ^
# SyntaxError: invalid decimal literal

# %%
my string = 'Hello World'   # No spaces in variable names
# Out:
#   File "/tmp/ipython-input-3984920328.py", line 1
#     my string = 'Hello World'
#        ^
# SyntaxError: invalid syntax

# %%
my_string = 'Hello World'

# %%
my@ = 'detrainings'  # only _ no special charachters
# Out:
#   File "/tmp/ipython-input-1041575940.py", line 1
#     my@ = 'detrainings'
#         ^
# SyntaxError: invalid syntax

# %%
myString = 'Hello World'

# %%
myString
# Out:
# 'Hello World'

# %%
#list = [1,2,3,4]
#str = 'Some one'

# %%
my_word = 'Test Word'

# %%
my_word = "Test Word"

# %%
my_para = """This is my line1
This is my line 2"""

# %%
my_para
# Out:
# 'This is my line1 \nThis is my line 2'

# %%
#Indentation

# %%
# if (i%2==0){
# print("Even")
# }
# else{
# print("Odd")
# }

# %%
i = 11

# %%
i%2   #  10%2
# Out:
# 1

# %%
if (i%2==0):
  print("Even")
else:
  print("Odd")
# Out:
# Odd

# %%
i = 10
if (i%2==0):
  print("Even")
else:
  print("Odd")
print("Out of loop")
# Out:
# Even
# Out of loop

# %%
i = 10
if (i%2==0):
  print("Even")
else:
  print("Odd")
  print("Out of loop")
# Out:
# Even

# %%
input("Enter your name: ")
# Out:
# Enter your name: Data Engineer
# 'Data Engineer'

# %%
name = input("Enter your name: ")
# Out:
# Enter your name: John

# %%
age = input("Enter age: ")
# Out:
# Enter age: 15

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# str

# %%
# type casting

# %%
age_num = int(age)

# %%
age_num
# Out:
# 15

# %%
type(age_num)
# Out:
# int

# %%
sentence = name + ' has an age of ' + age

# %%
sentence
# Out:
# 'John has an age of 15'

# %%
'a' + 'b'
# Out:
# 'ab'

# %%
name
# Out:
# 'John'

# %%
name + ' is the name'
# Out:
# 'John is the name'

# %%
name + ' is the name and his age is ' +  age
# Out:
# 'John is the name and his age is 15'

# %%
type(age)
# Out:
# str

# %%
#age = int(age)

# %%
type(age_num)
# Out:
# int

# %%
name + ' is the name and his age is ' +  age_num
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1428908292.py in <cell line: 0>()
# ----> 1 name + ' is the name and his age is ' +  age_num
#
# TypeError: can only concatenate str (not "int") to str

# %%
name + ' is the name and his age is ' +  str(age_num)
# Out:
# 'John is the name and his age is 15'

# %%
x = 'a'

# %%
int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-173064326.py in <cell line: 0>()
# ----> 1 int(x)
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
x = 10.5

# %%
float(x)
# Out:
# 10.5

# %%
int(x)
# Out:
# 10

# %%
a = 1

# %%
bool(a)
# Out:
# True

# %%
a = 0

# %%
bool(a)
# Out:
# False

# %%
bool(1000)
# Out:
# True

# %%
bool(-10000)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
None

# %%
## Capstone Project

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
email = input("Enter your email: ")
phone = input("Enter your phone number: ")
address = input("Enter your address: ")
# Out:
# Enter your name: JOhn
# Enter your age: 15
# Enter your emailhohn@email.com
# Enter your phone number99995555
# Enter your address785484144,hasvcgajs,dsf

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
email = input("Enter your email: ")
phone = input("Enter your phone number: ")
address = input("Enter your address: ")

print("**************************************")
print("Name = "+ name)
print("Age = "+ str(age))
print("email = "+ email)
print("phone = "+ phone)
print("address = "+ address)
print("**************************************")
# Out:
# Enter your name: John
# Enter your age: 25
# Enter your email: john@email,com
# Enter your phone number: 1478652314
# Enter your address: HYderbad
# **************************************
# Name = John
# Age = 25
# email = john@email,com
# phone = 1478652314
# address = HYderbad
# **************************************

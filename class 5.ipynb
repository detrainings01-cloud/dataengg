# %%
name = input("Enter student name ")
subjects = ['Maths','Science','Social']
scores = []
for i in subjects:
  cnt = 0
  #scores[cnt] = int(input(f"Enter marks in {i} "))
  scores.append(int(input(f"Enter marks in {i} ")))
  cnt += 1
# Out:
# Enter student name John
# Enter marks in Maths 85
# Enter marks in Science 95
# Enter marks in Social 85

# %%
sum(scores)
# Out:
# 265

# %%
sum(scores)/len(scores)
# Out:
# 88.33333333333333

# %%
s = "Hello"
#    01234

# %%
s[0]
# Out:
# 'H'

# %%
s[4]
# Out:
# 'o'

# %%
s[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1495924492.py in <cell line: 0>()
# ----> 1 s[5]
#
# IndexError: string index out of range

# %%
s = "Hello"

# %%
s[0:2]
# Out:
# 'He'

# %%
s = "Hello World"

# %%
s[0:5]
# Out:
# 'Hello'

# %%
s[-1]
# Out:
# 'd'

# %%
s[-5:]
# Out:
# 'World'

# %%
s
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s
# Out:
# 'Hello World'

# %%
s.lower()
# Out:
# 'hello world'

# %%
a = "Helo                         "

# %%
a.strip()
# Out:
# 'Helo'

# %%
a = """Hi, John is suferring from fever
He took some medicines to cure"""

# %%
a
# Out:
# 'Hi, John is suferring from fever \nHe took some medicines to cure'

# %%
a.count('to')
# Out:
# 2

# %%
s = "Hello, World"

# %%
s.find(',')
# Out:
# 5

# %%
a
# Out:
# 'Hi, John is suferring from fever \nHe took some medicines to cure'

# %%
a.index('John')
# Out:
# 4

# %%
s
# Out:
# 'Hello, World'

# %%
s.replace('World','People')
# Out:
# 'Hello, People'

# %%
s
# Out:
# 'Hello, World'

# %%
s.split()
# Out:
# ['Hello,', 'World']

# %%
#  List   Ordered collection of elements

# %%
my_list = ['apple','banana','cherry']  #  Ordered

# %%
my_list[1]
# Out:
# 'banana'

# %%
my_list
# Out:
# ['apple', 'banana', 'cherry']

# %%
my_list[1] = 'papaya'

# %%
my_list      #  changeable /   mutable
# Out:
# ['apple', 'papaya', 'cherry']

# %%
my_dup_list = ['apple','banana','cherry','banana','banana','cherry']

# %%
my_dup_list    #  duplicates
# Out:
# ['apple', 'banana', 'cherry', 'banana', 'banana', 'cherry']

# %%
len(my_dup_list)
# Out:
# 6

# %%
type(my_list)
# Out:
# list

# %%
my_list
# Out:
# ['apple', 'papaya', 'cherry']

# %%
my_list[2]
# Out:
# 'cherry'

# %%
my_list[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1388274891.py in <cell line: 0>()
# ----> 1 my_list[3]
#
# IndexError: list index out of range

# %%
my_list[-1]
# Out:
# 'cherry'

# %%
my_dup_list
# Out:
# ['apple', 'banana', 'cherry', 'banana', 'banana', 'cherry']

# %%
my_dup_list[0:2]
# Out:
# ['apple', 'banana']

# %%
my_dup_list[2:5]
# Out:
# ['cherry', 'banana', 'banana']

# %%
my_dup_list
# Out:
# ['apple', 'banana', 'cherry', 'banana', 'banana', 'cherry']

# %%
my_dup_list[0:3]
# Out:
# ['apple', 'banana', 'cherry']

# %%
my_dup_list[:3]
# Out:
# ['apple', 'banana', 'cherry']

# %%
my_dup_list[-1]
# Out:
# 'cherry'

# %%
my_list
# Out:
# ['apple', 'papaya', 'cherry']

# %%
my_list.append('banana')

# %%
my_list
# Out:
# ['apple', 'papaya', 'cherry', 'banana']

# %%
my_list.insert(2,'orange')

# %%
my_list
# Out:
# ['apple', 'papaya', 'orange', 'cherry', 'banana']

# %%
list_1 = [1,2,3,4,5]

# %%
list_2 = [10,20,30]

# %%
list_1.extend(list_2)

# %%
list_1
# Out:
# [1, 2, 3, 4, 5, 10, 20, 30]

# %%
list_2
# Out:
# [10, 20, 30]

# %%
my_list
# Out:
# ['apple', 'papaya', 'orange', 'cherry', 'banana']

# %%
my_list.remove('banana')

# %%
my_list
# Out:
# ['apple', 'papaya', 'orange', 'cherry']

# %%
my_dup_list
# Out:
# ['apple', 'banana', 'cherry', 'banana', 'banana', 'cherry']

# %%
my_dup_list.remove('banana')

# %%
my_dup_list
# Out:
# ['apple', 'cherry', 'banana', 'banana', 'cherry']

# %%
list_1
# Out:
# [1, 2, 3, 4, 5, 10, 20, 30]

# %%
list_1.pop()
# Out:
# 30

# %%
list_1
# Out:
# [1, 2, 3, 4, 5, 10, 20]

# %%
list_1.pop(1)
# Out:
# 2

# %%
list_1
# Out:
# [1, 3, 4, 5, 10, 20]

# %%
s
# Out:
# 'Hello, World'

# %%
del s

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1028141915.py in <cell line: 0>()
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
list_1
# Out:
# [1, 3, 4, 5, 10, 20]

# %%
list_1[2]
# Out:
# 4

# %%
del list_1[2]

# %%
list_1
# Out:
# [1, 3, 5, 10, 20]

# %%
del list_1

# %%
list_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2059798217.py in <cell line: 0>()
# ----> 1 list_1
#
# NameError: name 'list_1' is not defined

# %%
list_2
# Out:
# [10, 20, 30]

# %%
list_2.clear()

# %%
list_2
# Out:
# []

# %%
my_list
# Out:
# ['apple', 'papaya', 'orange', 'cherry']

# %%
for i in my_list:
  print(i)
# Out:
# apple
# papaya
# orange
# cherry

# %%
range(6)
# Out:
# range(0, 6)

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
my_list
# Out:
# ['apple', 'papaya', 'orange', 'cherry']

# %%
len(my_list)
# Out:
# 4

# %%
for i in range(len(my_list)):
  print(f"{i} index position has a value of {my_list[i]}")
# Out:
# 0 index position has a value of apple
# 1 index position has a value of papaya
# 2 index position has a value of orange
# 3 index position has a value of cherry

# %%
i = 0
while i < len(my_list):
  print(f"{i} index position has a value of {my_list[i]}")
  i += 1
# Out:
# 0 index position has a value of apple
# 1 index position has a value of papaya
# 2 index position has a value of orange
# 3 index position has a value of cherry

# %%
for i in my_list:
  print(i)
# Out:
# apple
# papaya
# orange
# cherry

# %%
[(i)  for i in my_list]
# Out:
# ['apple', 'papaya', 'orange', 'cherry']

# %%
list_1 = [10,20,30,40]

# %%
for i in list_1:
  print(i)
# Out:
# 10
# 20
# 30
# 40

# %%
for i in list_1:
  print(i*i)
# Out:
# 100
# 400
# 900
# 1600

# %%
[ i*i  for i in list_1 ]
# Out:
# [100, 400, 900, 1600]

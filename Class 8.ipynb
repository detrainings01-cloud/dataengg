# %%
# Dictionary   --> Store values with Key : Value

# %%
#   Ordered, changeable, will not allow duplicate keys

# %%
student = {"name":"John", "age":28, "city": "Hyderabad"}

# %%
type(student)
# Out:
# dict

# %%
student["name"]
# Out:
# 'John'

# %%
student #  Ordered
# Out:
# {'name': 'John', 'age': 28, 'city': 'Hyderabad'}

# %%
student["name"] = "Abe"

# %%
student  # updatable
# Out:
# {'name': 'Abe', 'age': 28, 'city': 'Hyderabad'}

# %%
my_dict = {'name':"John", "age":25, "name":"Abe"}   #  No duplicates

# %%
my_dict
# Out:
# {'name': 'Abe', 'age': 25}

# %%
len(my_dict)
# Out:
# 2

# %%
my_dict ={'name': 'Abe', 'age': 25}

# %%
student = {'name':'Abe','age':25, "elected_subjects" : ['Maths','English','Science']}

# %%
std_1 = dict(name="Abe",age = 25, elected_subjects = ['Maths','English','Science'])

# %%
std_1
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
type(std_1)
# Out:
# dict

# %%
std_1
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1['name']
# Out:
# 'Abe'

# %%
std_1['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3010392343.py in <cell line: 0>()
# ----> 1 std_1['Name']
#
# KeyError: 'Name'

# %%
std_1.get('name')
# Out:
# 'Abe'

# %%
std_1.get('Name')

# %%
std_1.get('Name','No Name')
# Out:
# 'No Name'

# %%
std_1
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1.get('elected_subjects')
# Out:
# ['Maths', 'English', 'Science']

# %%
std_1.get('elected_subjects',['No elected subjects'])
# Out:
# ['Maths', 'English', 'Science']

# %%
std_1
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1.keys()
# Out:
# dict_keys(['name', 'age', 'elected_subjects'])

# %%
std_1.values()
# Out:
# dict_values(['Abe', 25, ['Maths', 'English', 'Science']])

# %%
std_1.items()
# Out:
# dict_items([('name', 'Abe'), ('age', 25), ('elected_subjects', ['Maths', 'English', 'Science'])])

# %%
std_1
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1["age"] = 28

# %%
std_1
# Out:
# {'name': 'Abe', 'age': 28, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1.update({"name":"John"})

# %%
std_1
# Out:
# {'name': 'John',
#  'age': 28,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
students = [ {'name': 'Abe', 'age': 28, 'elected_subjects': ['Maths', 'English', 'Science']}
            , {'name': 'John', 'age': 32, 'elected_subjects': ['English', 'Science']}]

# %%
std_1
# Out:
# {'name': 'John',
#  'age': 28,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1.pop("age")
# Out:
# 28

# %%
std_1
# Out:
# {'name': 'John', 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1.popitem()
# Out:
# ('elected_subjects', ['Maths', 'English', 'Science'])

# %%
std_1
# Out:
# {'name': 'John'}

# %%
std_1 = {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
del std_1['age']

# %%
std_1
# Out:
# {'name': 'Abe', 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1.clear()

# %%
std_1
# Out:
# {}

# %%
std_1 = {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
std_1
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
del std_1

# %%
std_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2816115681.py in <cell line: 0>()
# ----> 1 std_1
#
# NameError: name 'std_1' is not defined

# %%
student
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
for i in student:
  print(i)
# Out:
# name
# age
# elected_subjects

# %%
for i in student:
  print(student[i])
# Out:
# Abe
# 25
# ['Maths', 'English', 'Science']

# %%
student['name']
# Out:
# 'Abe'

# %%
for i in student:
  print(f'{i} : {student[i]}')
# Out:
# name : Abe
# age : 25
# elected_subjects : ['Maths', 'English', 'Science']

# %%
for i in student:
  print(i)
# Out:
# name
# age
# elected_subjects

# %%
for i in student.keys():
  print(i)
# Out:
# name
# age
# elected_subjects

# %%
for i in student:
  print(student[i])
# Out:
# Abe
# 25
# ['Maths', 'English', 'Science']

# %%
for i in student.values():
  print(i)
# Out:
# Abe
# 25
# ['Maths', 'English', 'Science']

# %%
for i in student.items():
  print(i)
# Out:
# ('name', 'Abe')
# ('age', 25)
# ('elected_subjects', ['Maths', 'English', 'Science'])

# %%
for k,v in student.items():
  print(f'{k}:{v}')
# Out:
# name:Abe
# age:25
# elected_subjects:['Maths', 'English', 'Science']

# %%
student
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
my_std  = student

# %%
my_std
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
student['name']  = 'John'

# %%
student
# Out:
# {'name': 'John',
#  'age': 25,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
my_std
# Out:
# {'name': 'John',
#  'age': 25,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
student
# Out:
# {'name': 'John',
#  'age': 25,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
my_copy_std = student.copy()

# %%
my_copy_std
# Out:
# {'name': 'John',
#  'age': 25,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
student
# Out:
# {'name': 'John',
#  'age': 25,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
student['name'] = 'Abe'

# %%
student
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
my_copy_std
# Out:
# {'name': 'John',
#  'age': 25,
#  'elected_subjects': ['Maths', 'English', 'Science']}

# %%
my_org = { "std_1" : {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}
          , "std_2" : {'name': 'John', 'age': 28, 'elected_subjects': ['English', 'Science']}  }

# %%
my_org
# Out:
# {'std_1': {'name': 'Abe',
#   'age': 25,
#   'elected_subjects': ['Maths', 'English', 'Science']},
#  'std_2': {'name': 'John',
#   'age': 28,
#   'elected_subjects': ['English', 'Science']}}

# %%
my_org['std_1']
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}

# %%
my_org['std_1']['name']
# Out:
# 'Abe'

# %%
my_org
# Out:
# {'std_1': {'name': 'Abe',
#   'age': 25,
#   'elected_subjects': ['Maths', 'English', 'Science']},
#  'std_2': {'name': 'John',
#   'age': 28,
#   'elected_subjects': ['English', 'Science']}}

# %%
for std in my_org:
  print(my_org[std])
# Out:
# {'name': 'Abe', 'age': 25, 'elected_subjects': ['Maths', 'English', 'Science']}
# {'name': 'John', 'age': 28, 'elected_subjects': ['English', 'Science']}

# %%
my_org
# Out:
# {'std_1': {'name': 'Abe',
#   'age': 25,
#   'elected_subjects': ['Maths', 'English', 'Science']},
#  'std_2': {'name': 'John',
#   'age': 28,
#   'elected_subjects': ['English', 'Science']}}

# %%
for std in my_org:
  print(f"******{std} values****")
  for k,v in my_org[std].items():
    print(f"{k}:{v}")
# Out:
# ******std_1 values****
# name:Abe
# age:25
# elected_subjects:['Maths', 'English', 'Science']
# ******std_2 values****
# name:John
# age:28
# elected_subjects:['English', 'Science']

# %%
# Employee Management System
#  Add/Update/Delete the employee    (Ask for name, id and role)   ---     {"id":id, "name":"name", "role":role}
#  View the employees
#  Search the employee


employees = {'1':{"name":"Abe","role":"Architect"}}

# %%
employees['1']
# Out:
# {'name': 'Abe', 'role': 'Architect'}

# %%
employees['2'] = {"name":"John","role":"Project Manager"}

# %%
employees
# Out:
# {'1': {'name': 'Abe', 'role': 'Architect'},
#  '2': {'name': 'John', 'role': 'Project Manager'}}

# %%
employees['2']['role'] = 'Project Architect'

# %%
employees
# Out:
# {'1': {'name': 'Abe', 'role': 'Architect'},
#  '2': {'name': 'John', 'role': 'Project Architect'}}

# %%
del employees['2']

# %%
employees
# Out:
# {'1': {'name': 'Abe', 'role': 'Architect'}}

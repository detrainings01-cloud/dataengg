# %%
import pandas as pd

# %%
df = pd.read_csv("order.csv")

# %%
df
# Out:
#     order_id     customer_name           product  quantity   price  \
# 0       1001        John Smith            Laptop         1  999.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 3       1004       Emma Wilson           Monitor         1  349.99
# 4       1005       James Brown        Headphones         3  149.99
# 5       1006     Lisa Anderson         USB Cable        10    9.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 12      1013      Kevin Miller       Phone Stand         8   19.99
# ...

# %%
df.sort_values("product")
# Out:
#     order_id     customer_name           product  quantity   price  \
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 13      1014     Jessica Davis  External HDD 2TB         3   79.99
# 4       1005       James Brown        Headphones         3  149.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 0       1001        John Smith            Laptop         1  999.99
# 3       1004       Emma Wilson           Monitor         1  349.99
# 14      1015    Brandon Wilson     Monitor Stand         2   59.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 12      1013      Kevin Miller       Phone Stand         8   19.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# ...

# %%
df.sort_values("price")
# Out:
#     order_id     customer_name           product  quantity   price  \
# 5       1006     Lisa Anderson         USB Cable        10    9.99
# 12      1013      Kevin Miller       Phone Stand         8   19.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 14      1015    Brandon Wilson     Monitor Stand         2   59.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 13      1014     Jessica Davis  External HDD 2TB         3   79.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 4       1005       James Brown        Headphones         3  149.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# ...

# %%
df.sort_values("price",ascending=False)
# Out:
#     order_id     customer_name           product  quantity   price  \
# 0       1001        John Smith            Laptop         1  999.99
# 3       1004       Emma Wilson           Monitor         1  349.99
# 10      1011      Chris Garcia           Speaker         2  199.99
# 8       1009    David Martinez          RAM 16GB         1  159.99
# 4       1005       James Brown        Headphones         3  149.99
# 7       1008    Jennifer White           SSD 1TB         4  119.99
# 6       1007     Robert Taylor            Webcam         2   89.99
# 2       1003        Mike Davis          Keyboard         2   79.99
# 13      1014     Jessica Davis  External HDD 2TB         3   79.99
# 14      1015    Brandon Wilson     Monitor Stand         2   59.99
# 11      1012  Amanda Rodriguez         Desk Lamp         1   49.99
# 9       1010      Michelle Lee        Power Bank         6   39.99
# 1       1002     Sarah Johnson             Mouse         5   29.99
# ...

# %%
df = pd.DataFrame({"Name": ["Alice", "Bob", "Charlie","David","Eva"],
                   "Dept": ["HR", "IT", "Finance","HR","IT"],
                   "Salary": [70000, 80000, 90000, 80000, 85000],
                   "Age": [25, 26, 25, 28, 25]})

# %%
df
# Out:
#       Name     Dept  Salary  Age
# 0    Alice       HR   70000   25
# 1      Bob       IT   80000   26
# 2  Charlie  Finance   90000   25
# 3    David       HR   80000   28
# 4      Eva       IT   85000   25

# %%
df.sort_values("Dept",ascending=False)  # Single column sort
# Out:
#       Name     Dept  Salary  Age
# 1      Bob       IT   80000   26
# 4      Eva       IT   85000   25
# 0    Alice       HR   70000   25
# 3    David       HR   80000   28
# 2  Charlie  Finance   90000   25

# %%
df.sort_values(["Dept","Age"],ascending=[False,True]) # Multiple column sort
# Out:
#       Name     Dept  Salary  Age
# 4      Eva       IT   85000   25
# 1      Bob       IT   80000   26
# 0    Alice       HR   70000   25
# 3    David       HR   80000   28
# 2  Charlie  Finance   90000   25

# %%
df
# Out:
#       Name     Dept  Salary  Age
# 0    Alice       HR   70000   25
# 1      Bob       IT   80000   26
# 2  Charlie  Finance   90000   25
# 3    David       HR   80000   28
# 4      Eva       IT   85000   25

# %%
df.sort_values(["Dept","Age"],ascending=[False,True],inplace=True)

# %%
df
# Out:
#       Name     Dept  Salary  Age
# 4      Eva       IT   85000   25
# 1      Bob       IT   80000   26
# 0    Alice       HR   70000   25
# 3    David       HR   80000   28
# 2  Charlie  Finance   90000   25

# %%
df.sort_index()
# Out:
#       Name     Dept  Salary  Age
# 0    Alice       HR   70000   25
# 1      Bob       IT   80000   26
# 2  Charlie  Finance   90000   25
# 3    David       HR   80000   28
# 4      Eva       IT   85000   25

# %%
df
# Out:
#       Name     Dept  Salary  Age
# 4      Eva       IT   85000   25
# 1      Bob       IT   80000   26
# 0    Alice       HR   70000   25
# 3    David       HR   80000   28
# 2  Charlie  Finance   90000   25

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#       Name     Dept  Salary  Age
# 0    Alice       HR   70000   25
# 1      Bob       IT   80000   26
# 2  Charlie  Finance   90000   25
# 3    David       HR   80000   28
# 4      Eva       IT   85000   25

# %%
df = pd.DataFrame({"Name":["Abe","Bob","Charam"],"Age":[20,30,40],"City":["Hyd","Chennai","Blr"]})

# %%
df
# Out:
#      Name  Age     City
# 0     Abe   20      Hyd
# 1     Bob   30  Chennai
# 2  Charam   40      Blr

# %%
df.loc[1]
# Out:
# Name        Bob
# Age          30
# City    Chennai
# Name: 1, dtype: object

# %%
df = pd.DataFrame({"Name":["Abe","Bob","Charam"],"Age":[20,30,40],"City":["Hyd","Chennai","Blr"]}, index=["rec_1","rec_2","rec_3"])

# %%
df
# Out:
#          Name  Age     City
# rec_1     Abe   20      Hyd
# rec_2     Bob   30  Chennai
# rec_3  Charam   40      Blr

# %%
df.loc['rec_2']
# Out:
# Name        Bob
# Age          30
# City    Chennai
# Name: rec_2, dtype: object

# %%
df.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.loc[1]
#
# ...

# %%
df.iloc[1]
# Out:
# Name        Bob
# Age          30
# City    Chennai
# Name: rec_2, dtype: object

# %%
df
# Out:
#          Name  Age     City
# rec_1     Abe   20      Hyd
# rec_2     Bob   30  Chennai
# rec_3  Charam   40      Blr

# %%
df[df["Age"]>25]
# Out:
#          Name  Age     City
# rec_2     Bob   30  Chennai
# rec_3  Charam   40      Blr

# %%
data = {
    'Std_id': [101, 102, 103, 104, 105],
    'Student': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    "Maths": [85, 90, 78, 92, 88],
    "Science": [80, 85, 82, 88, 90],
    "English": [78, 82, 85, 90, 87]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English
# 0     101    Alice     85       80       78
# 1     102      Bob     90       85       82
# 2     103  Charlie     78       82       85
# 3     104    David     92       88       90
# 4     105      Eve     88       90       87

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Std_id   5 non-null      int64
#  1   Student  5 non-null      object
#  2   Maths    5 non-null      int64
#  3   Science  5 non-null      int64
#  4   English  5 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 332.0+ bytes

# %%
df.describe()
# Out:
#            Std_id      Maths    Science    English
# count    5.000000   5.000000   5.000000   5.000000
# mean   103.000000  86.600000  85.000000  84.400000
# std      1.581139   5.458938   4.123106   4.615192
# min    101.000000  78.000000  80.000000  78.000000
# 25%    102.000000  85.000000  82.000000  82.000000
# 50%    103.000000  88.000000  85.000000  85.000000
# 75%    104.000000  90.000000  88.000000  87.000000
# max    105.000000  92.000000  90.000000  90.000000

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English
# 0     101    Alice     85       80       78
# 1     102      Bob     90       85       82
# 2     103  Charlie     78       82       85
# 3     104    David     92       88       90
# 4     105      Eve     88       90       87

# %%
df["Maths"]
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# 4    88
# Name: Maths, dtype: int64

# %%
df["Maths"].mean()
# Out:
# np.float64(86.6)

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English
# 0     101    Alice     85       80       78
# 1     102      Bob     90       85       82
# 2     103  Charlie     78       82       85
# 3     104    David     92       88       90
# 4     105      Eve     88       90       87

# %%
df["Total_Marks"] = df["Maths"] + df["Science"] + df["English"]

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks
# 0     101    Alice     85       80       78          243
# 1     102      Bob     90       85       82          257
# 2     103  Charlie     78       82       85          245
# 3     104    David     92       88       90          270
# 4     105      Eve     88       90       87          265

# %%
df["Average"] = df["Total_Marks"] / 3

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average
# 0     101    Alice     85       80       78          243  81.000000
# 1     102      Bob     90       85       82          257  85.666667
# 2     103  Charlie     78       82       85          245  81.666667
# 3     104    David     92       88       90          270  90.000000
# 4     105      Eve     88       90       87          265  88.333333

# %%
df[df["Average"] > 85 ]
# Out:
#    Std_id Student  Maths  Science  English  Total_Marks    Average
# 1     102     Bob     90       85       82          257  85.666667
# 3     104   David     92       88       90          270  90.000000
# 4     105     Eve     88       90       87          265  88.333333

# %%
avg_df = df[df["Average"] > 85 ]

# %%
avg_df.sort_values("Average")
# Out:
#    Std_id Student  Maths  Science  English  Total_Marks    Average
# 1     102     Bob     90       85       82          257  85.666667
# 4     105     Eve     88       90       87          265  88.333333
# 3     104   David     92       88       90          270  90.000000

# %%
df[df["Average"] > 85 ].sort_values("Average")
# Out:
#    Std_id Student  Maths  Science  English  Total_Marks    Average
# 1     102     Bob     90       85       82          257  85.666667
# 4     105     Eve     88       90       87          265  88.333333
# 3     104   David     92       88       90          270  90.000000

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average
# 0     101    Alice     85       80       78          243  81.000000
# 1     102      Bob     90       85       82          257  85.666667
# 2     103  Charlie     78       82       85          245  81.666667
# 3     104    David     92       88       90          270  90.000000
# 4     105      Eve     88       90       87          265  88.333333

# %%
def assign_grade(avg):
    if avg >= 90:
        return "A"
    elif avg >= 80:
        return "B"
    else: 
        return "C"

# %%
df["Grade"] = df["Average"].apply(assign_grade)

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average Grade
# 0     101    Alice     85       80       78          243  81.000000     B
# 1     102      Bob     90       85       82          257  85.666667     B
# 2     103  Charlie     78       82       85          245  81.666667     B
# 3     104    David     92       88       90          270  90.000000     A
# 4     105      Eve     88       90       87          265  88.333333     B

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average Grade
# 0     101    Alice     85       80       78          243  81.000000     B
# 1     102      Bob     90       85       82          257  85.666667     B
# 2     103  Charlie     78       82       85          245  81.666667     B
# 3     104    David     92       88       90          270  90.000000     A
# 4     105      Eve     88       90       87          265  88.333333     B

# %%
df.to_csv("student_marks.csv")

# %%
df.to_csv("student_marks.csv",index=False)

# %%
del df["Grade"]

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average
# 0     101    Alice     85       80       78          243  81.000000
# 1     102      Bob     90       85       82          257  85.666667
# 2     103  Charlie     78       82       85          245  81.666667
# 3     104    David     92       88       90          270  90.000000
# 4     105      Eve     88       90       87          265  88.333333

# %%
df["Resul"] = df["Average"].apply( lambda x:  "Pass" if x>=85 else "Fail"    )

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average Resul
# 0     101    Alice     85       80       78          243  81.000000  Fail
# 1     102      Bob     90       85       82          257  85.666667  Pass
# 2     103  Charlie     78       82       85          245  81.666667  Fail
# 3     104    David     92       88       90          270  90.000000  Pass
# 4     105      Eve     88       90       87          265  88.333333  Pass

# %%
del df["Resul"]

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average
# 0     101    Alice     85       80       78          243  81.000000
# 1     102      Bob     90       85       82          257  85.666667
# 2     103  Charlie     78       82       85          245  81.666667
# 3     104    David     92       88       90          270  90.000000
# 4     105      Eve     88       90       87          265  88.333333

# %%
def check_pass(row): 
    if row["Maths"] >= 85 and row["Science"] >= 80 and row["English"] >= 80: 
        return "Pass"
    else: 
        return "Fail"

# %%
df["Res"] = df.apply(check_pass, axis=1 )

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average   Res
# 0     101    Alice     85       80       78          243  81.000000  Fail
# 1     102      Bob     90       85       82          257  85.666667  Pass
# 2     103  Charlie     78       82       85          245  81.666667  Fail
# 3     104    David     92       88       90          270  90.000000  Pass
# 4     105      Eve     88       90       87          265  88.333333  Pass

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average
# 0     101    Alice     85       80       78          243  81.000000
# 1     102      Bob     90       85       82          257  85.666667
# 2     103  Charlie     78       82       85          245  81.666667
# 3     104    David     92       88       90          270  90.000000
# 4     105      Eve     88       90       87          265  88.333333

# %%
df['Maths'].sum()
# Out:
# np.int64(433)

# %%
df['Maths'].apply(sum)  #  df['Maths']  this is series
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df['Maths'].apply(sum)  #  df['Maths']  this is series
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
df[['Maths']].apply(sum)
# Out:
# Maths    433
# dtype: int64

# %%
df['Maths'].sum()
# Out:
# np.int64(433)

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average   Res
# 0     101    Alice     85       80       78          243  81.000000  Fail
# 1     102      Bob     90       85       82          257  85.666667  Pass
# 2     103  Charlie     78       82       85          245  81.666667  Fail
# 3     104    David     92       88       90          270  90.000000  Pass
# 4     105      Eve     88       90       87          265  88.333333  Pass

# %%
df["Grade"] = df["Average"].apply(assign_grade)

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average   Res  \
# 0     101    Alice     85       80       78          243  81.000000  Fail
# 1     102      Bob     90       85       82          257  85.666667  Pass
# 2     103  Charlie     78       82       85          245  81.666667  Fail
# 3     104    David     92       88       90          270  90.000000  Pass
# 4     105      Eve     88       90       87          265  88.333333  Pass
#
#   Grade
# 0     B
# 1     B
# 2     B
# 3     A
# 4     B

# %%
# map 
grade_nums = {"A":1, "B":2, "C":3}

# %%
df["Grade_Num"] = df['Grade'].map(grade_nums)

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average   Res  \
# 0     101    Alice     85       80       78          243  81.000000  Fail
# 1     102      Bob     90       85       82          257  85.666667  Pass
# 2     103  Charlie     78       82       85          245  81.666667  Fail
# 3     104    David     92       88       90          270  90.000000  Pass
# 4     105      Eve     88       90       87          265  88.333333  Pass
#
#   Grade  Grade_Num
# 0     B          2
# 1     B          2
# 2     B          2
# 3     A          1
# 4     B          2

# %%
# df["Resul"] = df["Average"].apply( lambda x:  "Pass" if x>=85 else "Fail"    )

# %%
def res_def(avg):
    if avg >= 85: 
        return "Pass"
    else: 
        return "Fail"

# %%
df["Res_Map"] = df["Average"].map(res_def)

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average   Res  \
# 0     101    Alice     85       80       78          243  81.000000  Fail
# 1     102      Bob     90       85       82          257  85.666667  Pass
# 2     103  Charlie     78       82       85          245  81.666667  Fail
# 3     104    David     92       88       90          270  90.000000  Pass
# 4     105      Eve     88       90       87          265  88.333333  Pass
#
#   Grade  Grade_Num Res_Map
# 0     B          2    Fail
# 1     B          2    Pass
# 2     B          2    Fail
# 3     A          1    Pass
# 4     B          2    Pass

# %%
df["Category"] = df["Average"].map(  lambda x: "Topper" if x>85 else "Regular"    )

# %%
df
# Out:
#    Std_id  Student  Maths  Science  English  Total_Marks    Average   Res  \
# 0     101    Alice     85       80       78          243  81.000000  Fail
# 1     102      Bob     90       85       82          257  85.666667  Pass
# 2     103  Charlie     78       82       85          245  81.666667  Fail
# 3     104    David     92       88       90          270  90.000000  Pass
# 4     105      Eve     88       90       87          265  88.333333  Pass
#
#   Grade  Grade_Num Res_Map Category
# 0     B          2    Fail  Regular
# 1     B          2    Pass   Topper
# 2     B          2    Fail  Regular
# 3     A          1    Pass   Topper
# 4     B          2    Pass   Topper
